# %%
import pandas as pd

# %%
accepted = pd.read_csv('accepted_2007_to_2018Q4.csv',low_memory=False)

# %%
data = accepted.copy()

# %%
accepted.url.nunique()
# Out:
# 2260668

# %%
data.shape
# Out:
# (2260701, 151)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = data.drop('member_id',axis=1)

# %%
data = data[[i for i in data.columns if (data[i].isnull().sum()/data.shape[0]) * 100 < 40 ]]

# %%
plt.figure(figsize=(75,25))
(data.isnull().sum()/data.shape[0]).plot(kind='bar')
# Out:
# <AxesSubplot:>
